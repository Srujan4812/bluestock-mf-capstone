# %% [markdown]
# # 01 - Data Ingestion & Quality Profiling
#
# This notebook explores the raw files of the Bluestock Mutual Fund Analytics project. It profiles dataset shapes, column datatypes, nulls, duplicates, and checks AMFI codes referential integrity.

# %%
import os
import sys
from pathlib import Path
import pandas as pd

# Configure root paths
ROOT = Path(os.getcwd()).parent
sys.path.append(str(ROOT / 'scripts'))
import data_ingestion

data_ingestion.main()
# Out:
# Loaded 10 datasets from C:\Users\madhu\OneDrive\Desktop\bluestock_mf_capstone\data\raw
#
# ...
# DATASET: fund_master  (01_fund_master.csv)
# ...
# Shape: 40 rows x 15 columns
#
# -- Dtypes --
# amfi_code                      int64
# fund_house                    object
# scheme_name                   object
# category                      object
# sub_category                  object
# plan                          object
# launch_date           datetime64[ns]
# benchmark                     object
# expense_ratio_pct            float64
# exit_load_pct                float64
# min_sip_amount                 int64
# min_lumpsum_amount             int64
# fund_manager                  object
# risk_category                 object
# sebi_category_code            object
#
# -- Head --
# ...
