# %% [markdown]
# # 02 - Data Cleaning & Schema Normalization
#
# This notebook applies column-name normalisation, whitespace trimming, date parsing, integer coercion, and ffill() for weekend/holiday NAV gaps.

# %%
import os
import sys
from pathlib import Path
import pandas as pd

# Configure root paths
ROOT = Path(os.getcwd()).parent
sys.path.append(str(ROOT / 'scripts'))
import data_cleaning

outputs = data_cleaning.run()
for name, path in outputs.items():
    df = pd.read_csv(path)
    print(f"{name:<24} clean shape: {df.shape[0]:>5} rows x {df.shape[1]} columns")
# Out:
# 2026-06-08 18:22:54,847 [INFO] data_cleaning: fund_master: 40 -> 40 rows (removed 0)
# 2026-06-08 18:22:55,302 [INFO] data_cleaning: nav_history: 46000 -> 64320 rows (removed -18320)
# 2026-06-08 18:22:55,542 [INFO] data_cleaning: aum_by_fund_house: 90 -> 90 rows (removed 0)
# 2026-06-08 18:22:55,560 [INFO] data_cleaning: monthly_sip_inflows: 48 -> 48 rows (removed 0)
# 2026-06-08 18:22:55,576 [INFO] data_cleaning: category_inflows: 144 -> 144 rows (removed 0)
# 2026-06-08 18:22:55,589 [INFO] data_cleaning: industry_folio_count: 21 -> 21 rows (removed 0)
# 2026-06-08 18:22:55,614 [INFO] data_cleaning: scheme_performance: 40 -> 40 rows (removed 0)
# 2026-06-08 18:22:56,028 [INFO] data_cleaning: investor_transactions: 32778 -> 32778 rows (removed 0)
# 2026-06-08 18:22:56,350 [INFO] data_cleaning: portfolio_holdings: 322 -> 322 rows (removed 0)
# 2026-06-08 18:22:56,427 [INFO] data_cleaning: benchmark_indices: 8050 -> 8050 rows (removed 0)
# 2026-06-08 18:22:56,462 [INFO] data_cleaning: Cleaning complete: 10 datasets written to C:\Users\madhu\OneDrive\Desktop\bluestock_mf_capstone\data\processed
# fund_master              clean shape:    40 rows x 15 columns
# nav_history              clean shape: 64320 rows x 3 columns
# aum_by_fund_house        clean shape:    90 rows x 5 columns
# monthly_sip_inflows      clean shape:    48 rows x 6 columns
# category_inflows         clean shape:   144 rows x 3 columns
# industry_folio_count     clean shape:    21 rows x 6 columns
# scheme_performance       clean shape:    40 rows x 19 columns
# investor_transactions    clean shape: 32778 rows x 13 columns
# portfolio_holdings       clean shape:   322 rows x 8 columns
# benchmark_indices        clean shape:  8050 rows x 3 columns
